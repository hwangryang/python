# %% [markdown]
# Markdown 셀은 코드가 아닌 글을 쓰는 곳입니다.
# Run 을 하면 디자인이 입혀집니다.

# %% [markdown]
# # ![%EA%B0%95%EC%9D%B8%EA%B0%95%EC%9D%B82.png](attachment:%EA%B0%95%EC%9D%B8%EA%B0%95%EC%9D%B82.png)# 제목 heading

# %% [markdown]
# #githup 업로그할때는 img 태그로 해야함
# #이름은 영어로 바꿔주고
# #노트북 파일처럼 수정이 불편할떄는 지우고 다시 올리는게 편함
# <img src="soccer.png" />

# %%
a = [1,2,3,4,5]

# %%
a
# Out:
# [1, 2, 3, 4, 5]

# %%
# .tab
a.append(6)

# %%
a
# Out:
# [1, 2, 3, 4, 5, 6, 6, 6]

# %%
# shift + tab 함수 설명
a.append(7)

# %%
a
# Out:
# [1, 2, 3, 4, 5, 6, 6, 6, 6, 7]

# %%
# 객체? 객체 정보 조회
a?

# %%
# while 반복 횟수를 미리 알수 없을 때 사용
# 무한 반복이 되지 않도록 주의
x=6789329
i=1
while(2**i <x): #True면 실행
    i = i+1
    
i, 2**i
# Out:
# (23, 8388608)

# %%
#dictionary{키:값, 키:값...}
b = {'age':20, 'city':'Seoul'}
b
# Out:
# {'age': 20, 'city': 'Seoul'}

# %%
b['age'], b['city']
# Out:
# (20, 'Seoul')

# %%
# 키를 통해 수정
b['age'] += 10
b['age']
# Out:
# 30

# %%
# 키를 통해 값을 수정
b['part']='개발부'
b
# Out:
# {'age': 30, 'city': 'Seoul', 'part': '개발부'}

# %%
# 키를 통해서 제거
del b['age']
b
# Out:
# {'city': 'Seoul', 'part': '개발부'}

# %%
# 2차원 표 데이터(panal)에서 컬럼명이 키이고 값들이 value가 됩니다.
# 2차원 데이터 하나는 dictionary로 저장됩니다.
# 서울 100년간 온도 데이터에서 날짜 최저기온 최고기온 key가 됩니다.
b.keys()
# Out:
# dict_keys(['city', 'part'])
