# %%
import pandas as pd

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/All-time_table_of_the_FIFA_World_Cup', 
                header=2, index_col=0) # header 컬럼명이 몇번째 행?

# %%
len(df)
df
# Out:
# [                       Team   T    S    P   W   D   L    F    A    GD  T.1  \
#  №
#  1                    Brazil  21  +21  109  73  18  18  229  105  +124  237
#  2                Germany[A]  19  +17  109  67  20  22  226  125  +101  221
#  3                     Italy  18   −1   83  45  21  17  128   77   +51  156
#  4                 Argentina  17  +12   81  43  15  23  137   93   +44  144
#  5                    France  15   +6   66  34  13  19  120   77   +43  115
#  6                   England  15   +6   69  29  21  19   91   64   +27  108
#  7                     Spain  15  +11   63  30  15  18   99   72   +27  105
#  8               Netherlands  10   −1   50  27  12  11   86   48   +38   93
#  9                   Uruguay  13   +3   56  24  12  20   87   74   +13   84
#  10                   Sweden  12   +1   51  19  13  19   80   73    +7   70
#  11                  Belgium  13   +2   48  20   9  19   68   72    −4   69
# ...

# %%
worldcup = df[0]
worldcup.head()
# Out:
#          Team   T    S    P   W   D   L    F    A    GD  T.1    A.1  T.2  \
# №
# 1      Brazil  21  +21  109  73  18  18  229  105  +124  237  2.174  164
# 2  Germany[A]  19  +17  109  67  20  22  226  125  +101  221  2.028  154
# 3       Italy  18   −1   83  45  21  17  128   77   +51  156  1.880  111
# 4   Argentina  17  +12   81  43  15  23  137   93   +44  144  1.778  101
# 5      France  15   +6   66  34  13  19  120   77   +43  115  1.742   81
#
#      A.2  T.3    A.3                              Best finish Confederation
# №
# 1  1.505  193  1.771  Champion (1958, 1962, 1970, 1994, 2002)      CONMEBOL
# 2  1.413  182  1.670        Champion (1954, 1974, 1990, 2014)          UEFA
# 3  1.337  125  1.506        Champion (1934, 1938, 1982, 2006)          UEFA
# 4  1.247  120  1.481                    Champion (1978, 1986)      CONMEBOL
# 5  1.227  100  1.515                    Champion (1998, 2018)          UEFA

# %%
type(worldcup)
# Out:
# pandas.core.frame.DataFrame

# %%
worldcup.columns
# Out:
# Index(['Team', 'T', 'S', 'P', 'W', 'D', 'L', 'F', 'A', 'GD', 'T.1', 'A.1',
#        'T.2', 'A.2', 'T.3', 'A.3', 'Best finish', 'Confederation'],
#       dtype='object')

# %%
worldcup.shape
# Out:
# (79, 18)

# %%
worldcup.sort_values('T', ascending=False).to_excel('월드컵기록.xlsx')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-57-2b1a78d2fbf6> in <module>
# ----> 1 worldcup.sort_values('T', ascending=False).to_excel('월드컵기록.xlsx')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    2125         formatter.write(excel_writer, sheet_name=sheet_name, startrow=startrow,
#    2126                         startcol=startcol, freeze_panes=freeze_panes,
# -> 2127                         engine=engine)
#    2128
#    2129     def to_json(self, path_or_buf=None, orient=None, date_format=None,
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
# ...

# %%
url = 'https://finance.naver.com/'
df = pd.read_html(url, encoding='cp949' , 
                header=0, index_col=0) # header 컬럼명이 몇번째 행?

# %%
df[0]
# Out:
#          Unnamed: 1       1주  Unnamed: 3       누적  Unnamed: 5       추천일
# 종목명
# NaN             NaN      NaN         NaN      NaN         NaN       NaN
# 아이앤씨            NaN  +17.80%         NaN  +14.02%         NaN  19.06.14
# 이녹스첨단소재         NaN  +16.34%         NaN  +31.22%         NaN  19.05.23
# 파수닷컴            NaN  +12.41%         NaN  +21.10%         NaN  19.05.21
# 인선이엔티           NaN  +11.08%         NaN  -13.37%         NaN  19.05.02
# 디바이스이엔지         NaN  +10.48%         NaN    0.00%         NaN  19.03.20

# %%
wise = df[0]

# %%
wise_save = wise_save.replace('%', '',regex=True) # % -> 공백으로 대체
wise_save
# Out:
#              1주      누적       추천일
# 종목명
# 아이앤씨     +17.80  +14.02  19.06.14
# 이녹스첨단소재  +16.34  +31.22  19.05.23
# 파수닷컴     +12.41  +21.10  19.05.21
# 인선이엔티    +11.08  -13.37  19.05.02
# 디바이스이엔지  +10.48    0.00  19.03.20

# %%
wise_save = wise.iloc[1:, 1::2] # 1열 부터 2칸씩

# %%
wise_save.to_excel('wise_save1.xlsx')

# %%
# 259 pandas 란 panel datas 데이터 분석용 라이브러리
# values 를 numpy로 관리
# 컬럼 > 시리즈, 표 > 데이터 프레임

# %%
# 260
index = pd.date_range('1/1/2000', periods=8)
index
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08'],
#               dtype='datetime64[ns]', freq='D')

# %%
# dataframe의 구성요소(values, index, columns)
import numpy as np
df = pd.DataFrame(data=np.random.rand(8,3), index=index,columns=list('abc'))
#df = pd.DataFrame(data=np.random.rand(8,3), index=index,columns=list(['A', 'B', 'C']))

# %%
df
# Out:
#                    a         b         c
# 2000-01-01  0.003193  0.815169  0.461965
# 2000-01-02  0.697053  0.684071  0.930029
# 2000-01-03  0.168548  0.500325  0.904116
# 2000-01-04  0.821517  0.984919  0.923155
# 2000-01-05  0.818387  0.898881  0.663090
# 2000-01-06  0.764624  0.754549  0.524435
# 2000-01-07  0.930491  0.125927  0.433608
# 2000-01-08  0.446776  0.742317  0.949914

# %%
np.sum(df, axis=0)
# Out:
# a    4.650588
# b    5.506158
# c    5.790313
# dtype: float64

# %%
df['D'] = df['a'] / df['b']
df['E']  =np.sum(df, axis=1)
df.head()
df.to_csv('test.csv', sep=',', float_format='%.2f')

# %%
# 0.5 보다 큰 값만 뽑기 x[x>0.5] -> Boolean Mask
df[df > 0.5]
# Out:
#                    a         b         c         D          E
# 2000-01-01       NaN  0.815169       NaN       NaN   3.852731
# 2000-01-02  0.697053  0.684071  0.930029  1.018977   9.990392
# 2000-01-03       NaN  0.500325  0.904116       NaN   5.729596
# 2000-01-04  0.821517  0.984919  0.923155  0.834096  10.691061
# 2000-01-05  0.818387  0.898881  0.663090  0.910451   9.872426
# 2000-01-06  0.764624  0.754549  0.524435  1.013352   9.170879
# 2000-01-07  0.930491       NaN       NaN  7.389112  26.637414
# 2000-01-08       NaN  0.742317  0.949914  0.601867   8.222622

# %%
a=df['a']
a[a>0.5]
# Out:
# 2000-01-01    0.976554
# 2000-01-02    0.560331
# 2000-01-06    0.745927
# 2000-01-07    0.505342
# 2000-01-08    0.856963
# Name: a, dtype: float64

# %%
df.T #대각선 기준으로 회전(x축 -> y축)
# Out:
#    2000-01-01  2000-01-02  2000-01-03  2000-01-04  2000-01-05  2000-01-06  \
# a    0.976554    0.560331    0.176543    0.013529    0.179075    0.745927
# b    0.351364    0.102948    0.288290    0.056232    0.899592    0.539238
# c    0.099471    0.082868    0.169421    0.550628    0.708823    0.071106
#
#    2000-01-07  2000-01-08
# a    0.505342    0.856963
# b    0.927494    0.193904
# c    0.911747    0.001579

# %%
df.T.T
# Out:
#                    a         b         c
# 2000-01-01  0.976554  0.351364  0.099471
# 2000-01-02  0.560331  0.102948  0.082868
# 2000-01-03  0.176543  0.288290  0.169421
# 2000-01-04  0.013529  0.056232  0.550628
# 2000-01-05  0.179075  0.899592  0.708823
# 2000-01-06  0.745927  0.539238  0.071106
# 2000-01-07  0.505342  0.927494  0.911747
# 2000-01-08  0.856963  0.193904  0.001579

# %%
a=df['a']
b=df['b']

# %%
a_b_mean = (a + b)/2

# %%
a_b_mean
# Out:
# 2000-01-01    0.663959
# 2000-01-02    0.331639
# 2000-01-03    0.232417
# 2000-01-04    0.034881
# 2000-01-05    0.539333
# 2000-01-06    0.642582
# 2000-01-07    0.716418
# 2000-01-08    0.525433
# Freq: D, dtype: float64

# %%
d={'a':4, 'b':5}
d['c'] = 10
del d['a']
d
# Out:
# {'b': 5, 'c': 10}

# %%
df['ab_mean'] = a_b_mean

# %%
del df['a']

# %%
df
# Out:
#                    b         c   ab_mean
# 2000-01-01  0.351364  0.099471  0.663959
# 2000-01-02  0.102948  0.082868  0.331639
# 2000-01-03  0.288290  0.169421  0.232417
# 2000-01-04  0.056232  0.550628  0.034881
# 2000-01-05  0.899592  0.708823  0.539333
# 2000-01-06  0.539238  0.071106  0.642582
# 2000-01-07  0.927494  0.911747  0.716418
# 2000-01-08  0.193904  0.001579  0.525433

# %%
# 268 pandas로 인구 구조 분석하기

# %%
df = pd.read_csv('age.csv',index_col=0)
df.shape #103
# Out:
# (3841, 103)

# %%
df = df.dropna() # 누락 행 제거

# %%
df = df.replace(',', '', regex=True)

# %%
a = df.astype('int')

# %%
a
# Out:
#                                    2019년02월_계_총인구수  2019년02월_계_연령구간인구수  \
# 행정구역
# 서울특별시  (1100000000)                        9770638             9770638
# 서울특별시 종로구 (1111000000)                      152880              152880
# 서울특별시 종로구 청운효자동(1111051500)                  13010               13010
# 서울특별시 종로구 사직동(1111053000)                     9584                9584
# 서울특별시 종로구 삼청동(1111054000)                     2820                2820
# 서울특별시 종로구 부암동(1111055000)                    10142               10142
# 서울특별시 종로구 평창동(1111056000)                    18881               18881
# 서울특별시 종로구 무악동(1111057000)                     8415                8415
# 서울특별시 종로구 교남동(1111058000)                    10704               10704
# 서울특별시 종로구 가회동(1111060000)                     4412                4412
# 서울특별시 종로구 종로1.2.3.4가동(1111061500)             7347                7347
# 서울특별시 종로구 종로5.6가동(1111063000)                 5220                5220
# ...

# %%
# 1. 인구를 총 인구수로 나눈다. 인구수 > 비율
b = a.div(a.iloc[:, 0], axis=0)
c = b.iloc[:,2:] 
c
# Out:
#                                    2019년02월_계_0세  2019년02월_계_1세  \
# 행정구역
# 서울특별시  (1100000000)                     0.005500       0.006100
# 서울특별시 종로구 (1111000000)                  0.003879       0.004468
# 서울특별시 종로구 청운효자동(1111051500)             0.005073       0.006072
# 서울특별시 종로구 사직동(1111053000)               0.004487       0.005217
# 서울특별시 종로구 삼청동(1111054000)               0.003191       0.005319
# 서울특별시 종로구 부암동(1111055000)               0.003352       0.005029
# 서울특별시 종로구 평창동(1111056000)               0.004290       0.005720
# 서울특별시 종로구 무악동(1111057000)               0.002377       0.005466
# 서울특별시 종로구 교남동(1111058000)               0.009062       0.007380
# 서울특별시 종로구 가회동(1111060000)               0.003173       0.003853
# 서울특별시 종로구 종로1.2.3.4가동(1111061500)       0.002450       0.002178
# 서울특별시 종로구 종로5.6가동(1111063000)           0.001916       0.002299
# 서울특별시 종로구 이화동(1111064000)               0.002963       0.002716
# 서울특별시 종로구 혜화동(1111065000)               0.002351       0.002997
# ...

# %%
#2. 궁금한 지역의 이름을 입력받는다.
name = input("원하는 지역이 이름을 입력하세요 : ")
name
# Out:
# 원하는 지역이 이름을 입력하세요 : 신도림동
# '신도림동'

# %%
c.index #1열
# Out:
# Index(['서울특별시  (1100000000)', '서울특별시 종로구 (1111000000)',
#        '서울특별시 종로구 청운효자동(1111051500)', '서울특별시 종로구 사직동(1111053000)',
#        '서울특별시 종로구 삼청동(1111054000)', '서울특별시 종로구 부암동(1111055000)',
#        '서울특별시 종로구 평창동(1111056000)', '서울특별시 종로구 무악동(1111057000)',
#        '서울특별시 종로구 교남동(1111058000)', '서울특별시 종로구 가회동(1111060000)',
#        ...
#        '제주특별자치도 서귀포시 중앙동(5013053000)', '제주특별자치도 서귀포시 천지동(5013054000)',
#        '제주특별자치도 서귀포시 효돈동(5013055000)', '제주특별자치도 서귀포시 영천동(5013056000)',
#        '제주특별자치도 서귀포시 동홍동(5013057000)', '제주특별자치도 서귀포시 서홍동(5013058000)',
#        '제주특별자치도 서귀포시 대륜동(5013059000)', '제주특별자치도 서귀포시 대천동(5013060000)',
#        '제주특별자치도 서귀포시 중문동(5013061000)', '제주특별자치도 서귀포시 예래동(5013062000)'],
#       dtype='object', name='행정구역', length=3841)

# %%
c.index.str.contains(name).sum()
mask = c.index.str.contains(name)
df2 = c[mask]
df2.head(2)
# Out:
#                             2019년02월_계_0세  2019년02월_계_1세  2019년02월_계_2세  \
# 행정구역
# 서울특별시 구로구 신도림동(1153051000)       0.008747       0.008962       0.010894
#
#                             2019년02월_계_3세  2019년02월_계_4세  2019년02월_계_5세  \
# 행정구역
# 서울특별시 구로구 신도림동(1153051000)       0.011082       0.010438       0.010948
#
#                             2019년02월_계_6세  2019년02월_계_7세  2019년02월_계_8세  \
# 행정구역
# 서울특별시 구로구 신도림동(1153051000)       0.011189       0.011645       0.011028
#
#                             2019년02월_계_9세  ...  2019년02월_계_91세  \
# 행정구역                                       ...
# 서울특별시 구로구 신도림동(1153051000)       0.010384  ...        0.000402
#
#                             2019년02월_계_92세  2019년02월_계_93세  2019년02월_계_94세  \
# 행정구역
# 서울특별시 구로구 신도림동(1153051000)        0.000349        0.000322        0.000134
#
#                             2019년02월_계_95세  2019년02월_계_96세  2019년02월_계_97세  \
# 행정구역
# 서울특별시 구로구 신도림동(1153051000)        0.000215        0.000134        0.000107
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.rc('font', family='Malgun Gothic')
df2.T.plot()

# %%
df = c
x = df.sub(df2.iloc[0], axis=1) # 원본과 내가 관심있는 지역의 0번째 행을 뺀다
y = np.abs(x)
#y = np.power(x,2) #제곱
z = y.sum(axis=1) #나이별 차이를 다 누적시킨다.

# %%
i = z.sort_values().index[:5]
i
# Out:
# Index(['서울특별시 구로구 신도림동(1153051000)', '서울특별시 구로구 구로제1동(1153052000)',
#        '경기도 하남시 (4145000000)', '경기도 광명시 소하2동(4121065000)',
#        '경상북도 포항시 남구 오천읍(4711125600)'],
#       dtype='object', name='행정구역')

# %%
df.loc[i].T.plot()
