# %%
import numpy as np 
import pandas as pd 

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.preprocessing import MinMaxScaler

from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import GradientBoostingClassifier

from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

import wordcloud

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize 

import os
print(os.listdir("/"))
#os.environ['PATH'] += os.pathsep + 'C:\Program Files (x86)\Graphviz2.38\/bin/'
# Out:
# ['$Recycle.Bin', 'Documents and Settings', 'hiberfil.sys', 'Intel', 'kafka_2.12', 'MSOCache', 'pagefile.sys', 'PerfLogs', 'Program Files', 'Program Files (x86)', 'ProgramData', 'Recovery', 'swapfile.sys', 'System Volume Information', 'tmp', 'Users', 'Windows']

# %%
def print_validation_report(y_true, y_pred):
    print("Classification Report")
    print(classification_report(y_true, y_pred))
    acc_sc = accuracy_score(y_true, y_pred)
    print("Accuracy : "+ str(acc_sc))
    
    return acc_sc

# %%
def plot_confusion_matrix(y_true, y_pred):
    mtx = confusion_matrix(y_true, y_pred)
    #fig, ax = plt.subplots(figsize=(4,4))
    sns.heatmap(mtx, annot=True, fmt='d', linewidths=.5,  
                cmap="Blues", cbar=False, ax=ax)
    #  square=True,
    plt.ylabel('true label')
    plt.xlabel('predicted label')

# %%
data = pd.read_csv("spam.csv",encoding='latin-1')
data.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
data = data.drop(["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"], axis=1)
data = data.rename(columns={"v1":"label", "v2":"text"})

# %%
data.describe()
# Out:
#        label                    text
# count   5572                    5572
# unique     2                    5169
# top      ham  Sorry, I'll call later
# freq    4825                      30

# %%
data.groupby("label").describe()
# Out:
#        text
#       count unique                                                top freq
# label
# ham    4825   4516                             Sorry, I'll call later   30
# spam    747    653  Please call our customer service representativ...    4

# %%
data.head()
# Out:
#   label                                               text
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
data.label.value_counts()
# Out:
# ham     4825
# spam     747
# Name: label, dtype: int64

# %%
data.label.value_counts().plot.bar();

# %%
data['spam'] = data['label'].map( {'spam': 1, 'ham': 0} ).astype(int)
data.head(15)
# Out:
#    label                                               text  spam
# 0    ham  Go until jurong point, crazy.. Available only ...     0
# 1    ham                      Ok lar... Joking wif u oni...     0
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...     1
# 3    ham  U dun say so early hor... U c already then say...     0
# 4    ham  Nah I don't think he goes to usf, he lives aro...     0
# 5   spam  FreeMsg Hey there darling it's been 3 week's n...     1
# 6    ham  Even my brother is not like to speak with me. ...     0
# 7    ham  As per your request 'Melle Melle (Oru Minnamin...     0
# 8   spam  WINNER!! As a valued network customer you have...     1
# 9   spam  Had your mobile 11 months or more? U R entitle...     1
# 10   ham  I'm gonna be home soon and i don't want to tal...     0
# 11  spam  SIX chances to win CASH! From 100 to 20,000 po...     1
# 12  spam  URGENT! You have won a 1 week FREE membership ...     1
# 13   ham  I've been searching for the right words to tha...     0
# 14   ham                I HAVE A DATE ON SUNDAY WITH WILL!!     0

# %%
data['length'] = data['text'].apply(len)

# %%
data.head(10)
# Out:
#   label                                               text  spam  length
# 0   ham  Go until jurong point, crazy.. Available only ...     0     111
# 1   ham                      Ok lar... Joking wif u oni...     0      29
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...     1     155
# 3   ham  U dun say so early hor... U c already then say...     0      49
# 4   ham  Nah I don't think he goes to usf, he lives aro...     0      61
# 5  spam  FreeMsg Hey there darling it's been 3 week's n...     1     148
# 6   ham  Even my brother is not like to speak with me. ...     0      77
# 7   ham  As per your request 'Melle Melle (Oru Minnamin...     0     160
# 8  spam  WINNER!! As a valued network customer you have...     1     158
# 9  spam  Had your mobile 11 months or more? U R entitle...     1     154

# %%
data.hist(column='length',by='label',bins=60,figsize=(12,4));
plt.xlim(-40,950);

# %%
data_ham  = data[data['spam'] == 0].copy()
data_spam = data[data['spam'] == 1].copy()
# 분류

# %%
def show_wordcloud(data_spam_or_ham, title):
    text = ' '.join(data_spam_or_ham['text'].astype(str).tolist())
    stopwords = set(wordcloud.STOPWORDS)
    
    fig_wordcloud = wordcloud.WordCloud(stopwords=stopwords,background_color='lightgrey',
                    colormap='viridis', width=800, height=600).generate(text)
    
    plt.figure(figsize=(10,7), frameon=True)
    plt.imshow(fig_wordcloud)  
    plt.axis('off')
    plt.title(title, fontsize=20 )
    plt.show()

# %%
show_wordcloud(data_ham, "Ham messages")

# %%
show_wordcloud(data_spam, "Spam messages")

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
from nltk.corpus import stopwords
stopwords.words("english")[100:110]
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      85                 try:
# ---> 86                     root = nltk.data.find('{}/{}'.format(self.subdir, zip_name))
#      87                 except LookupError:
#
# ~\Anaconda3\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     698     resource_not_found = '\n%s\n%s\n%s\n' % (sep, msg, sep)
# --> 699     raise LookupError(resource_not_found)
#     700
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   Attempted to load corpora/stopwords.zip/stopwords/
#
#   Searched in:
#     - 'C:\\Users\\wtime/nltk_data'
#     - 'C:\\Users\\wtime\\Anaconda3\\nltk_data'
#     - 'C:\\Users\\wtime\\Anaconda3\\share\\nltk_data'
#     - 'C:\\Users\\wtime\\Anaconda3\\lib\\nltk_data'
#     - 'C:\\Users\\wtime\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# <ipython-input-57-208ffde8b434> in <module>
#       1 from nltk.corpus import stopwords
# ----> 2 stopwords.words("english")[100:110]
#
# ~\Anaconda3\lib\site-packages\nltk\corpus\util.py in __getattr__(self, attr)
#     121             raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
#     122
# --> 123         self.__load()
#     124         # This looks circular, but its not, since __load() changes our
#     125         # __class__ to something new:
#
# ~\Anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      86                     root = nltk.data.find('{}/{}'.format(self.subdir, zip_name))
#      87                 except LookupError:
# ---> 88                     raise e
#      89
#      90         # Load the corpus.
#
# ~\Anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      81         else:
#      82             try:
# ---> 83                 root = nltk.data.find('{}/{}'.format(self.subdir, self.__name))
#      84             except LookupError as e:
#      85                 try:
#
# ~\Anaconda3\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     697     sep = '*' * 70
#     698     resource_not_found = '\n%s\n%s\n%s\n' % (sep, msg, sep)
# --> 699     raise LookupError(resource_not_found)
#     700
#     701
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   Attempted to load corpora/stopwords
#
#   Searched in:
#     - 'C:\\Users\\wtime/nltk_data'
#     - 'C:\\Users\\wtime\\Anaconda3\\nltk_data'
#     - 'C:\\Users\\wtime\\Anaconda3\\share\\nltk_data'
#     - 'C:\\Users\\wtime\\Anaconda3\\lib\\nltk_data'
#     - 'C:\\Users\\wtime\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************

# %%
data['text'].apply(remove_punctuation_and_stopwords).head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-a98b044363e3> in <module>
# ----> 1 data['text'].apply(remove_punctuation_and_stopwords).head()
#
# NameError: name 'remove_punctuation_and_stopwords' is not defined
